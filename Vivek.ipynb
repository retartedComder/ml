# %% [markdown]
# <a href="https://colab.research.google.com/github/retartedComder/ml/blob/main/Vivek.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
data = {"id":[1,2,3,4], "Name" : ["vivek" , "kumar" , "yadav" , "abc"], "Places" : ["amritsar" , "pune" , "jamshedpur" , "mumbai" ]}

# %%
import pandas as pd

# %%
df = dp.DataFrame (data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-b6a961d2d703> in <cell line: 1>()
# ----> 1 df = dp.DataFrame (data)
#
# NameError: name 'dp' is not defined

# %%
df = pd.DataFrame (data)

# %%
df.tail(2)
# Out:
#    id   Name      Places
# 2   3  yadav  jamshedpur
# 3   4    abc      mumbai

# %%
df.describe()
# Out:
#              id
# count  4.000000
# mean   2.500000
# std    1.290994
# min    1.000000
# 25%    1.750000
# 50%    2.500000
# 75%    3.250000
# max    4.000000

# %%
df.head()
# Out:
#    id   Name      Places
# 0   1  vivek    amritsar
# 1   2  kumar        pune
# 2   3  yadav  jamshedpur
# 3   4    abc      mumbai
